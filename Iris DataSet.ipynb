# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
df=pd.read_csv('IRIS.csv',encoding='unicode_escape')
df.head(120)
# Out:
#      sepal_length  sepal_width  petal_length  petal_width         species
# 0             5.1          3.5           1.4          0.2     Iris-setosa
# 1             4.9          3.0           1.4          0.2     Iris-setosa
# 2             4.7          3.2           1.3          0.2     Iris-setosa
# 3             4.6          3.1           1.5          0.2     Iris-setosa
# 4             5.0          3.6           1.4          0.2     Iris-setosa
# ..            ...          ...           ...          ...             ...
# 115           6.4          3.2           5.3          2.3  Iris-virginica
# 116           6.5          3.0           5.5          1.8  Iris-virginica
# 117           7.7          3.8           6.7          2.2  Iris-virginica
# 118           7.7          2.6           6.9          2.3  Iris-virginica
# 119           6.0          2.2           5.0          1.5  Iris-virginica
#
# [120 rows x 5 columns]

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
df=pd.read_csv('IRIS.csv',encoding='unicode_escape')
df.head(120)
sb.lmplot(x='sepal_length', y='sepal_width',data=df,hue='species',fit_reg=True)
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt
df=pd.read_csv('IRIS.csv',encoding='unicode_escape')
df.head(120)
sb.lmplot(x='petal_length', y='petal_width', data=df,hue='species',fit_reg=True)
plt.show()

# %%
sb.boxplot(df['sepal_length'],notch=True,orient='v',color='Green',width=0.74)
plt.show()

# %%
sb.boxplot(df['sepal_width'],notch=True,orient='v',color='black',width=0.74)
plt.show()

# %%
sb.boxplot(df['petal_length'],notch=True,orient='v',color='yellow',width=0.74)
plt.show()

# %%
sb.boxplot(df['petal_length'],notch=True,orient='v',color='red',width=0.74)
plt.show()

# %%
plt.hist(df['sepal_length'],bins=20,ec='White',color='HotPink')
plt.show()

# %%
plt.hist(df['sepal_width'],bins=20,ec='White',color='black')
plt.show()

# %%
plt.hist(df['petal_length'],bins=20,ec='red',color='black')
plt.show()

# %%
plt.hist(df['petal_width'],bins=20,ec='black',color='green')
plt.show()

# %%
import pandas as pd
import numpy as np
import seaborn as sb
import matplotlib.pyplot as plt

df = pd.read_csv("IRIS.csv", encoding='unicode_escape')

# Create the boxplots
plt.boxplot([df['sepal_length'], df['sepal_width'], df['petal_length'], df['petal_width']], labels=['sepal length', 'sepal width', 'petal length', 'petal width'])

# Show the plot
plt.show()
